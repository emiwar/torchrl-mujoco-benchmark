# %%
import numpy as np
import torchrl
import importlib
import custom_torchrl_env

# %%
importlib.reload(custom_torchrl_env)
# Out:
# <module 'custom_torchrl_env' from '/home/emil/Development/custom_torchrl_env/custom_torchrl_env.py'>

# %%
env = custom_torchrl_env.RodentRunEnv(batch_size=(47,17))
torchrl.envs.utils.check_env_specs(env)
transEnv = torchrl.envs.TransformedEnv(
    env,
    torchrl.envs.Compose(
        # normalize observations
        torchrl.envs.ObservationNorm(in_keys=["observation"]),
        torchrl.envs.StepCounter(max_steps=5),
        torchrl.envs.RewardSum()
    ),
)
transEnv.transform[0].init_stats(num_iter=48, cat_dim=0, reduce_dim=tuple(range(len(env.batch_size)+1)))
torchrl.envs.utils.check_env_specs(transEnv)
rollout = transEnv.rollout(10, break_when_any_done=False)
# Out:
# 2024-04-05 17:32:03,362 [torchrl][INFO] check_env_specs succeeded!
# 2024-04-05 17:32:04,279 [torchrl][INFO] check_env_specs succeeded!

# %%
td = transEnv.reset()
for t in range(3):
    td["action"] = transEnv.rand_action()["action"]
    td_, td = transEnv.step_and_maybe_reset(td)
td["done"][..., ::2, :] = True
td = transEnv.maybe_reset(td)
td_, td = transEnv.step_and_maybe_reset(td)
#td_, td = transEnv.step_and_maybe_reset(td)
td["step_count"].squeeze()
# Out:
# tensor([[1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1],
#         [1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1],
#         [1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1],
#         [1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1],
#         [1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1],
#         [1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1],
#         [1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1],
#         [1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1],
#         [1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1],
#         [1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1],
#         [1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1],
#         [1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1],
#         [1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1],
#         [1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1],
#         [1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1],
#         [1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1],
#         [1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1],
#         [1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1],
#         [1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1],
#         [1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1],
#         [1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1],
#         [1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1],
#         [1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1],
#         [1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1],
#         [1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1],
#         [1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1],
#         [1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1],
#         [1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1],
#         [1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1],
#         [1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1],
#         [1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1],
#         [1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1],
#         [1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1],
#         [1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1],
#         [1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1],
#         [1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1],
#         [1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1],
#         [1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1],
#         [1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1],
#         [1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1],
#         [1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1],
#         [1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1],
#         [1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1],
#         [1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1],
#         [1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1],
#         [1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1],
#         [1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1]])

# %%
td["done"]
# Out:
# tensor([[[False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False]],
#
#         [[False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False]],
#
#         [[False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False]],
#
#         [[False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False]],
#
#         [[False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False]],
#
#         [[False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False]],
#
#         [[False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False]],
#
#         [[False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False]],
#
#         [[False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False]],
#
#         [[False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False]],
#
#         [[False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False]],
#
#         [[False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False]],
#
#         [[False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False]],
#
#         [[False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False]],
#
#         [[False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False]],
#
#         [[False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False]],
#
#         [[False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False]],
#
#         [[False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False]],
#
#         [[False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False]],
#
#         [[False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False]],
#
#         [[False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False]],
#
#         [[False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False]],
#
#         [[False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False]],
#
#         [[False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False]],
#
#         [[False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False]],
#
#         [[False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False]],
#
#         [[False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False]],
#
#         [[False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False]],
#
#         [[False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False]],
#
#         [[False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False]],
#
#         [[False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False]],
#
#         [[False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False]],
#
#         [[False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False]],
#
#         [[False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False]],
#
#         [[False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False]],
#
#         [[False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False]],
#
#         [[False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False]],
#
#         [[False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False]],
#
#         [[False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False]],
#
#         [[False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False]],
#
#         [[False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False]],
#
#         [[False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False]],
#
#         [[False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False]],
#
#         [[False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False]],
#
#         [[False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False]],
#
#         [[False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False]],
#
#         [[False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False],
#          [False]]])

# %%
transEnv.done_spec
# Out:
# CompositeSpec(
#     done: DiscreteTensorSpec(
#         shape=torch.Size([47, 1]),
#         space=DiscreteBox(n=2),
#         device=cpu,
#         dtype=torch.bool,
#         domain=discrete),
#     terminated: DiscreteTensorSpec(
#         shape=torch.Size([47, 1]),
#         space=DiscreteBox(n=2),
#         device=cpu,
#         dtype=torch.bool,
#         domain=discrete),
#     truncated: DiscreteTensorSpec(
#         shape=torch.Size([47, 1]),
#         space=DiscreteBox(n=2),
#         device=cpu,
#         dtype=torch.bool,
#         domain=discrete), device=cpu, shape=torch.Size([47]))

# %%
td_[("next", "step_count")]
# Out:
# tensor([[4],
#         [4],
#         [4],
#         [4],
#         [4],
#         [4],
#         [4],
#         [4],
#         [4],
#         [4],
#         [4],
#         [4],
#         [4],
#         [4],
#         [4],
#         [4],
#         [4],
#         [4],
#         [4],
#         [4],
#         [4],
#         [4],
#         [4],
#         [4],
#         [4],
#         [4],
#         [4],
#         [4],
#         [4],
#         [4],
#         [4],
#         [4],
#         [4],
#         [4],
#         [4],
#         [4],
#         [4],
#         [4],
#         [4],
#         [4],
#         [4],
#         [4],
#         [4],
#         [4],
#         [4],
#         [4],
#         [4]])

# %%
transEnv._simple_done
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~/pyenvs/build_mujoco/lib/python3.10/site-packages/torchrl/envs/transforms/transforms.py:865, in TransformedEnv.__getattr__(self, attr)
#     864 try:
# --> 865     return super().__getattr__(
#     866         attr
#     867     )  # make sure that appropriate exceptions are raised
#     868 except Exception as err:
#
# File ~/pyenvs/build_mujoco/lib/python3.10/site-packages/torch/nn/modules/module.py:1688, in Module.__getattr__(self, name)
#    1687         return modules[name]
# -> 1688 raise AttributeError(f"'{type(self).__name__}' object has no attribute '{name}'")
#
# AttributeError: 'TransformedEnv' object has no attribute '_simple_done'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# Cell In[73], line 1
# ----> 1 transEnv._simple_done
#
# File ~/pyenvs/build_mujoco/lib/python3.10/site-packages/torchrl/envs/transforms/transforms.py:877, in TransformedEnv.__getattr__(self, attr)
#     875 elif "base_env" in self.__dir__():
#     876     base_env = self.__getattr__("base_env")
# --> 877     return getattr(base_env, attr)
#     878 raise AttributeError(
#     879     f"env not set in {self.__class__.__name__}, cannot access {attr}"
#     880 ) from err
#
# File ~/pyenvs/build_mujoco/lib/python3.10/site-packages/torch/nn/modules/module.py:1688, in Module.__getattr__(self, name)
#    1686     if name in modules:
#    1687         return modules[name]
# -> 1688 raise AttributeError(f"'{type(self).__name__}' object has no attribute '{name}'")
#
# AttributeError: 'RodentRunEnv' object has no attribute '_simple_done'

# %%
transEnv.rand_action()["action"]
# Out:
# tensor([[-0.7168,  0.6856,  0.5460,  ..., -0.4156,  0.1290, -0.6670],
#         [ 0.0838,  0.8155,  0.7097,  ...,  0.7834,  0.2277, -0.9487],
#         [-0.3697,  0.9156,  0.6169,  ...,  0.8236, -0.6108,  0.1140],
#         ...,
#         [ 0.6618, -0.5534,  0.9632,  ...,  0.4257, -0.2014,  0.5587],
#         [ 0.3576, -0.0321, -0.2948,  ..., -0.7316,  0.0589, -0.7645],
#         [-0.0488,  0.3100, -0.0805,  ...,  0.7618, -0.2398,  0.8818]])

# %%
td#["action"]
# Out:
# (TensorDict(
#      fields={
#          action: Tensor(shape=torch.Size([47, 30]), device=cpu, dtype=torch.float32, is_shared=False),
#          done: Tensor(shape=torch.Size([47, 1]), device=cpu, dtype=torch.bool, is_shared=False),
#          episode_reward: Tensor(shape=torch.Size([47, 1]), device=cpu, dtype=torch.float32, is_shared=False),
#          next: TensorDict(
#              fields={
#                  done: Tensor(shape=torch.Size([47, 1]), device=cpu, dtype=torch.bool, is_shared=False),
#                  episode_reward: Tensor(shape=torch.Size([47, 1]), device=cpu, dtype=torch.float32, is_shared=False),
#                  observation: Tensor(shape=torch.Size([47, 178]), device=cpu, dtype=torch.float32, is_shared=False),
#                  reward: Tensor(shape=torch.Size([47, 1]), device=cpu, dtype=torch.float32, is_shared=False),
#                  step_count: Tensor(shape=torch.Size([47, 1]), device=cpu, dtype=torch.int64, is_shared=False),
#                  terminated: Tensor(shape=torch.Size([47, 1]), device=cpu, dtype=torch.bool, is_shared=False),
#                  truncated: Tensor(shape=torch.Size([47, 1]), device=cpu, dtype=torch.bool, is_shared=False)},
#              batch_size=torch.Size([47]),
#              device=None,
#              is_shared=False),
#          observation: Tensor(shape=torch.Size([47, 178]), device=cpu, dtype=torch.float32, is_shared=False),
#          step_count: Tensor(shape=torch.Size([47, 1]), device=cpu, dtype=torch.int64, is_shared=False),
#          terminated: Tensor(shape=torch.Size([47, 1]), device=cpu, dtype=torch.bool, is_shared=False),
#          truncated: Tensor(shape=torch.Size([47, 1]), device=cpu, dtype=torch.bool, is_shared=False)},
#      batch_size=torch.Size([47]),
#      device=None,
#      is_shared=False),
#  TensorDict(
#      fields={
#          action: Tensor(shape=torch.Size([47, 30]), device=cpu, dtype=torch.float32, is_shared=False),
#          done: Tensor(shape=torch.Size([47, 1]), device=cpu, dtype=torch.bool, is_shared=False),
#          episode_reward: Tensor(shape=torch.Size([47, 1]), device=cpu, dtype=torch.float32, is_shared=False),
#          observation: Tensor(shape=torch.Size([47, 178]), device=cpu, dtype=torch.float32, is_shared=False),
#          step_count: Tensor(shape=torch.Size([47, 1]), device=cpu, dtype=torch.int64, is_shared=False),
#          terminated: Tensor(shape=torch.Size([47, 1]), device=cpu, dtype=torch.bool, is_shared=False),
#          truncated: Tensor(shape=torch.Size([47, 1]), device=cpu, dtype=torch.bool, is_shared=False)},
#      batch_size=torch.Size([47]),
#      device=None,
#      is_shared=False))

# %%
dmContEnv = torchrl.envs.DMControlEnv("humanoid", "stand")
batchDmContEnv = torchrl.envs.SerialEnv(7, lambda: torchrl.envs.DMControlEnv("humanoid", "stand"))

# %%
dmContEnv.rand_step()
# Out:
# TensorDict(
#     fields={
#         action: Tensor(shape=torch.Size([21]), device=cpu, dtype=torch.float64, is_shared=False),
#         next: TensorDict(
#             fields={
#                 com_velocity: Tensor(shape=torch.Size([3]), device=cpu, dtype=torch.float64, is_shared=False),
#                 done: Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.bool, is_shared=False),
#                 extremities: Tensor(shape=torch.Size([12]), device=cpu, dtype=torch.float64, is_shared=False),
#                 head_height: Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float64, is_shared=False),
#                 joint_angles: Tensor(shape=torch.Size([21]), device=cpu, dtype=torch.float64, is_shared=False),
#                 reward: Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float64, is_shared=False),
#                 terminated: Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.bool, is_shared=False),
#                 torso_vertical: Tensor(shape=torch.Size([3]), device=cpu, dtype=torch.float64, is_shared=False),
#                 truncated: Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.bool, is_shared=False),
#                 velocity: Tensor(shape=torch.Size([27]), device=cpu, dtype=torch.float64, is_shared=False)},
#             batch_size=torch.Size([]),
#             device=cpu,
#             is_shared=False)},
#     batch_size=torch.Size([]),
#     device=cpu,
#     is_shared=False)

# %%
batchDmContEnv.rand_step()
# Out:
# TensorDict(
#     fields={
#         action: Tensor(shape=torch.Size([7, 21]), device=cpu, dtype=torch.float64, is_shared=False),
#         next: TensorDict(
#             fields={
#                 com_velocity: Tensor(shape=torch.Size([7, 3]), device=cpu, dtype=torch.float64, is_shared=False),
#                 done: Tensor(shape=torch.Size([7, 1]), device=cpu, dtype=torch.bool, is_shared=False),
#                 extremities: Tensor(shape=torch.Size([7, 12]), device=cpu, dtype=torch.float64, is_shared=False),
#                 head_height: Tensor(shape=torch.Size([7, 1]), device=cpu, dtype=torch.float64, is_shared=False),
#                 joint_angles: Tensor(shape=torch.Size([7, 21]), device=cpu, dtype=torch.float64, is_shared=False),
#                 reward: Tensor(shape=torch.Size([7, 1]), device=cpu, dtype=torch.float64, is_shared=False),
#                 terminated: Tensor(shape=torch.Size([7, 1]), device=cpu, dtype=torch.bool, is_shared=False),
#                 torso_vertical: Tensor(shape=torch.Size([7, 3]), device=cpu, dtype=torch.float64, is_shared=False),
#                 truncated: Tensor(shape=torch.Size([7, 1]), device=cpu, dtype=torch.bool, is_shared=False),
#                 velocity: Tensor(shape=torch.Size([7, 27]), device=cpu, dtype=torch.float64, is_shared=False)},
#             batch_size=torch.Size([7]),
#             device=cpu,
#             is_shared=False)},
#     batch_size=torch.Size([7]),
#     device=cpu,
#     is_shared=False)

# %%
transBatchDmContEnv = torchrl.envs.TransformedEnv(
    batchDmContEnv,
    torchrl.envs.Compose(
        # normalize observations
        #torchrl.envs.ObservationNorm(in_keys=["observation"]),
        #torchrl.envs.StepCounter(max_steps=5),
        torchrl.envs.RewardSum()
    ),
)

# %%
transBatchDmContEnv.rand_step()
# Out:
# TensorDict(
#     fields={
#         action: Tensor(shape=torch.Size([7, 21]), device=cpu, dtype=torch.float64, is_shared=False),
#         next: TensorDict(
#             fields={
#                 com_velocity: Tensor(shape=torch.Size([7, 3]), device=cpu, dtype=torch.float64, is_shared=False),
#                 done: Tensor(shape=torch.Size([7, 1]), device=cpu, dtype=torch.bool, is_shared=False),
#                 episode_reward: Tensor(shape=torch.Size([7, 1]), device=cpu, dtype=torch.float64, is_shared=False),
#                 extremities: Tensor(shape=torch.Size([7, 12]), device=cpu, dtype=torch.float64, is_shared=False),
#                 head_height: Tensor(shape=torch.Size([7, 1]), device=cpu, dtype=torch.float64, is_shared=False),
#                 joint_angles: Tensor(shape=torch.Size([7, 21]), device=cpu, dtype=torch.float64, is_shared=False),
#                 reward: Tensor(shape=torch.Size([7, 1]), device=cpu, dtype=torch.float64, is_shared=False),
#                 terminated: Tensor(shape=torch.Size([7, 1]), device=cpu, dtype=torch.bool, is_shared=False),
#                 torso_vertical: Tensor(shape=torch.Size([7, 3]), device=cpu, dtype=torch.float64, is_shared=False),
#                 truncated: Tensor(shape=torch.Size([7, 1]), device=cpu, dtype=torch.bool, is_shared=False),
#                 velocity: Tensor(shape=torch.Size([7, 27]), device=cpu, dtype=torch.float64, is_shared=False)},
#             batch_size=torch.Size([7]),
#             device=cpu,
#             is_shared=False)},
#     batch_size=torch.Size([7]),
#     device=cpu,
#     is_shared=False)

# %%
transBatchDmContEnv.reward_spec
# Out:
# UnboundedContinuousTensorSpec(
#     shape=torch.Size([7, 1]),
#     space=None,
#     device=cpu,
#     dtype=torch.float64,
#     domain=continuous)

# %%
batchDmContEnv.done_spec
# Out:
# CompositeSpec(
#     done: DiscreteTensorSpec(
#         shape=torch.Size([7, 1]),
#         space=DiscreteBox(n=2),
#         device=cpu,
#         dtype=torch.bool,
#         domain=discrete),
#     truncated: DiscreteTensorSpec(
#         shape=torch.Size([7, 1]),
#         space=DiscreteBox(n=2),
#         device=cpu,
#         dtype=torch.bool,
#         domain=discrete),
#     terminated: DiscreteTensorSpec(
#         shape=torch.Size([7, 1]),
#         space=DiscreteBox(n=2),
#         device=cpu,
#         dtype=torch.bool,
#         domain=discrete), device=cpu, shape=torch.Size([7]))

# %%
env.done_spec
# Out:
# CompositeSpec(
#     done: DiscreteTensorSpec(
#         shape=torch.Size([47, 1]),
#         space=DiscreteBox(n=2),
#         device=cpu,
#         dtype=torch.bool,
#         domain=discrete),
#     terminated: DiscreteTensorSpec(
#         shape=torch.Size([47, 1]),
#         space=DiscreteBox(n=2),
#         device=cpu,
#         dtype=torch.bool,
#         domain=discrete), device=cpu, shape=torch.Size([47]))

# %%
env.reward_spec
# Out:
# UnboundedContinuousTensorSpec(
#     shape=torch.Size([47, 1]),
#     space=None,
#     device=cpu,
#     dtype=torch.float32,
#     domain=continuous)

# %%
batchDmContEnv.reward_spec
# Out:
# UnboundedContinuousTensorSpec(
#     shape=torch.Size([7, 1]),
#     space=None,
#     device=cpu,
#     dtype=torch.float64,
#     domain=continuous)

# %%
transBatchDmContEnv.rand_step()
# Out:
# TensorDict(
#     fields={
#         action: Tensor(shape=torch.Size([7, 21]), device=cpu, dtype=torch.float64, is_shared=False),
#         next: TensorDict(
#             fields={
#                 com_velocity: Tensor(shape=torch.Size([7, 3]), device=cpu, dtype=torch.float64, is_shared=False),
#                 done: Tensor(shape=torch.Size([7, 1]), device=cpu, dtype=torch.bool, is_shared=False),
#                 episode_reward: Tensor(shape=torch.Size([7, 1]), device=cpu, dtype=torch.float64, is_shared=False),
#                 extremities: Tensor(shape=torch.Size([7, 12]), device=cpu, dtype=torch.float64, is_shared=False),
#                 head_height: Tensor(shape=torch.Size([7, 1]), device=cpu, dtype=torch.float64, is_shared=False),
#                 joint_angles: Tensor(shape=torch.Size([7, 21]), device=cpu, dtype=torch.float64, is_shared=False),
#                 reward: Tensor(shape=torch.Size([7, 1]), device=cpu, dtype=torch.float64, is_shared=False),
#                 terminated: Tensor(shape=torch.Size([7, 1]), device=cpu, dtype=torch.bool, is_shared=False),
#                 torso_vertical: Tensor(shape=torch.Size([7, 3]), device=cpu, dtype=torch.float64, is_shared=False),
#                 truncated: Tensor(shape=torch.Size([7, 1]), device=cpu, dtype=torch.bool, is_shared=False),
#                 velocity: Tensor(shape=torch.Size([7, 27]), device=cpu, dtype=torch.float64, is_shared=False)},
#             batch_size=torch.Size([7]),
#             device=cpu,
#             is_shared=False)},
#     batch_size=torch.Size([7]),
#     device=cpu,
#     is_shared=False)

# %%
transEnv.rand_step()
# Out:
# TensorDict(
#     fields={
#         action: Tensor(shape=torch.Size([47, 30]), device=cpu, dtype=torch.float32, is_shared=False),
#         next: TensorDict(
#             fields={
#                 done: Tensor(shape=torch.Size([47, 1]), device=cpu, dtype=torch.bool, is_shared=False),
#                 episode_reward: Tensor(shape=torch.Size([47]), device=cpu, dtype=torch.float32, is_shared=False),
#                 observation: Tensor(shape=torch.Size([47, 178]), device=cpu, dtype=torch.float32, is_shared=False),
#                 reward: Tensor(shape=torch.Size([47, 1]), device=cpu, dtype=torch.float32, is_shared=False),
#                 terminated: Tensor(shape=torch.Size([47, 1]), device=cpu, dtype=torch.bool, is_shared=False)},
#             batch_size=torch.Size([47]),
#             device=cpu,
#             is_shared=False)},
#     batch_size=torch.Size([47]),
#     device=cpu,
#     is_shared=False)

# %%
batchDmContEnv.reward_spec
# Out:
# UnboundedContinuousTensorSpec(
#     shape=torch.Size([7, 1]),
#     space=None,
#     device=cpu,
#     dtype=torch.float64,
#     domain=continuous)

# %%
env.reward_spec
# Out:
# UnboundedContinuousTensorSpec(
#     shape=torch.Size([47, 1]),
#     space=None,
#     device=cpu,
#     dtype=torch.float32,
#     domain=continuous)
